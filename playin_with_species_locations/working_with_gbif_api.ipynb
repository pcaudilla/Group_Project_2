# %%
import requests
import pandas as pd

# %%
url1 = "http://api.gbif.org/v1/species?name=Varanus%20mitchelli"

# %%
testing_gbif = requests.get(url1).json()

# %%
testing_gbif
# Out:
# {'offset': 0,
#  'limit': 20,
#  'endOfRecords': True,
#  'results': [{'key': 2470695,
#    'nubKey': 2470695,
#    'nameKey': 11698356,
#    'taxonID': 'gbif:2470695',
#    'sourceTaxonKey': 128885051,
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'order': 'Squamata',
#    'family': 'Varanidae',
#    'genus': 'Varanus',
#    'species': 'Varanus mitchelli',
#    'kingdomKey': 1,
#    'phylumKey': 44,
#    'classKey': 358,
#    'orderKey': 715,
#    'familyKey': 5023,
#    'genusKey': 2470872,
#    'speciesKey': 2470695,
#    'datasetKey': 'd7dddbf4-2cf0-4f39-9b2a-bb099caae36c',
#    'constituentKey': '7ddf754f-d193-4cc9-b351-99906754a03b',
#    'parentKey': 2470872,
#    'parent': 'Varanus',
#    'scientificName': 'Varanus mitchelli Mertens, 1958',
#    'canonicalName': 'Varanus mitchelli',
#    'authorship': 'Mertens, 1958',
#    'nameType': 'SCIENTIFIC',
#    'rank': 'SPECIES',
#    'origin': 'SOURCE',
#    'taxonomicStatus': 'ACCEPTED',
# ...
